# %%
import sklearn as sk
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.callbacks import EarlyStopping
from keras.losses import mean_squared_error
from keras import backend as K
from keras.layers import ReLU
from keras.layers import LeakyReLU
from keras.optimizers import Adam
from keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %%
import os
for dirname, _, filenames in os.walk('../../Datas/ashre-energy/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ../../Datas/ashre-energy/FE_train_V1_noNan.pkl
# ../../Datas/ashre-energy/FE_test_V1_noNan.pkl
# ../../Datas/ashre-energy/test_df.pkl
# ../../Datas/ashre-energy/FE_train_V1.pkl
# ../../Datas/ashre-energy/FE_test_V1.pkl
# ../../Datas/ashre-energy/test.pkl
# ../../Datas/ashre-energy/FE_X_train_V1_noNan.pkl
# ../../Datas/ashre-energy/train.pkl
# ../../Datas/ashre-energy/building_metadata.pkl
# ../../Datas/ashre-energy/weather_train.pkl
# ../../Datas/ashre-energy/test.csv
# ../../Datas/ashre-energy/sample_submission.csv
# ../../Datas/ashre-energy/train.csv
# ../../Datas/ashre-energy/FE_X_test_V1_noNan.pkl
# ../../Datas/ashre-energy/FE_y_train_V1_noNan.pkl
# ../../Datas/ashre-energy/weather_test.pkl
# ../../Datas/ashre-energy/building_metadata.csv
# ../../Datas/ashre-energy/weather_test.csv
# ../../Datas/ashre-energy/weather_train.csv
# ../../Datas/ashre-energy/submission.csv
# ../../Datas/ashre-energy/.gitignore
# ../../Datas/ashre-energy/train_df.pkl
# ...

# %%
import matplotlib.pyplot as plt

# %%
X_train = pd.read_pickle('../../Datas/ashre-energy/FE_X_train_V1_noNan.pkl')
y_train  = pd.read_pickle('../../Datas/ashre-energy/FE_y_train_V1_noNan.pkl')
X_test = pd.read_pickle('../../Datas/ashre-energy/FE_test_V1_noNan.pkl')

# %%
# Y_train = train_df['meter_reading']
# X_train = train_df.drop(['meter_reading'],axis=1)
# del train_df
# X_test = test_df.to_numpy()
# del test_df

# %%
IN_DIM = X_train.shape[1]
TRAIN_LEN = X_train.shape[0]
print(X_train.shape)
# Out:
# (20216100, 48)

# %%
def plotHistory(history):
    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

# %%
def pred(model):
    return model.predict(X_final)

# %%
def RMSLE(y_true,y_pred):
    return K.sqrt(K.mean(K.square(K.log(K.abs(y_pred+1))-K.log(K.abs(y_true+1)))))

# %%
Adam_ES50 = Sequential()
Adam_ES50.add(Dense(512,input_dim = IN_DIM,kernel_regularizer=l2(0.05)))
Adam_ES50.add(ReLU())
Adam_ES50.add(Dense(256,kernel_regularizer=l2(0.01)))
Adam_ES50.add(ReLU())
Adam_ES50.add(Dense(256,kernel_regularizer=l2(0.01)))
Adam_ES50.add(ReLU())
Adam_ES50.add(Dense(128,kernel_regularizer=l2(0.01)))
Adam_ES50.add(ReLU())
Adam_ES50.add(Dense(1))
Adam_ES50.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 512)               25088
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# ...

# %%
es = EarlyStopping(monitor='val_loss', patience = 50, mode='min', restore_best_weights=True, verbose=1)
Adam_ES50.compile(loss=RMSLE, optimizer='adam',metrics=['mean_absolute_error','mean_squared_error'])

# %%
history = Adam_ES50.fit(x=X_train,y=y_train,batch_size=1000,epochs=5000,validation_split=0.3,verbose=1,callbacks=[es],shuffle=True)
# Out:
# Train on 14151270 samples, validate on 6064830 samples
# Epoch 1/5000
# 14151270/14151270 [==============================] - 438s 31us/step - loss: 15.1459 - mean_absolute_error: 1968847.2500 - mean_squared_error: 19389243981824.0000 - val_loss: 17.2625 - val_mean_absolute_error: 2082706.1250 - val_mean_squared_error: 9372336914432.0000
# Epoch 2/5000
# 14151270/14151270 [==============================] - 437s 31us/step - loss: 13.9295 - mean_absolute_error: 1302450.6250 - mean_squared_error: 11468437192704.0000 - val_loss: 11.5132 - val_mean_absolute_error: 533184.9375 - val_mean_squared_error: 619624136704.0000
# Epoch 3/5000
# 14151270/14151270 [==============================] - 433s 31us/step - loss: 12.2109 - mean_absolute_error: 1051527.1250 - mean_squared_error: 5429737291776.0000 - val_loss: 13.4652 - val_mean_absolute_error: 1537963.6250 - val_mean_squared_error: 5139375587328.0000
# Epoch 4/5000
# ...

# %%
Adam_ES50.save('../../Models/ashre-energy/Adam_ES50.h5')
plt = plotHistory(history)
